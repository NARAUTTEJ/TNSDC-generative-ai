# %%
# IMPORTANT: RUN THIS CELL IN ORDER TO IMPORT YOUR KAGGLE DATA SOURCES
# TO THE CORRECT LOCATION (/kaggle/input) IN YOUR NOTEBOOK,
# THEN FEEL FREE TO DELETE THIS CELL.
# NOTE: THIS NOTEBOOK ENVIRONMENT DIFFERS FROM KAGGLE'S PYTHON
# ENVIRONMENT SO THERE MAY BE MISSING LIBRARIES USED BY YOUR
# NOTEBOOK.

import os
import sys
from tempfile import NamedTemporaryFile
from urllib.request import urlopen
from urllib.parse import unquote, urlparse
from urllib.error import HTTPError
from zipfile import ZipFile
import tarfile
import shutil

CHUNK_SIZE = 40960
DATA_SOURCE_MAPPING = 'keras-pretrained-models:https%3A%2F%2Fstorage.googleapis.com%2Fkaggle-data-sets%2F2798%2F7251%2Fbundle%2Farchive.zip%3FX-Goog-Algorithm%3DGOOG4-RSA-SHA256%26X-Goog-Credential%3Dgcp-kaggle-com%2540kaggle-161607.iam.gserviceaccount.com%252F20240330%252Fauto%252Fstorage%252Fgoog4_request%26X-Goog-Date%3D20240330T112810Z%26X-Goog-Expires%3D259200%26X-Goog-SignedHeaders%3Dhost%26X-Goog-Signature%...,brain-mri-images-for-brain-tumor-detection:https%3A%2F%2Fstorage.googleapis.com%2Fkaggle-data-sets%2F165566%2F377107%2Fbundle%2Farchive.zip%3FX-Goog-Algorithm%3DGOOG4-RSA-SHA256%26X-Goog-Credential%3Dgcp-kaggle-com%2540kaggle-161607.iam.gserviceaccount.com%252F20240330%252Fauto%252Fstorage%252Fgoog4_request%26X-Goog-Date%3D20240330T112810Z%26X-Goog-Expires%3D259200%26X-Goog-SignedHeaders%3Dhost%26X-Goog-Signature%...'

KAGGLE_INPUT_PATH='/kaggle/input'
KAGGLE_WORKING_PATH='/kaggle/working'
KAGGLE_SYMLINK='kaggle'

# !umount /kaggle/input/ 2> /dev/null
shutil.rmtree('/kaggle/input', ignore_errors=True)
os.makedirs(KAGGLE_INPUT_PATH, 0o777, exist_ok=True)
os.makedirs(KAGGLE_WORKING_PATH, 0o777, exist_ok=True)

try:
  os.symlink(KAGGLE_INPUT_PATH, os.path.join("..", 'input'), target_is_directory=True)
except FileExistsError:
  pass
try:
  os.symlink(KAGGLE_WORKING_PATH, os.path.join("..", 'working'), target_is_directory=True)
except FileExistsError:
  pass

for data_source_mapping in DATA_SOURCE_MAPPING.split(','):
    directory, download_url_encoded = data_source_mapping.split(':')
    download_url = unquote(download_url_encoded)
    filename = urlparse(download_url).path
    destination_path = os.path.join(KAGGLE_INPUT_PATH, directory)
    try:
        with urlopen(download_url) as fileres, NamedTemporaryFile() as tfile:
            total_length = fileres.headers['content-length']
            print(f'Downloading {directory}, {total_length} bytes compressed')
            dl = 0
            data = fileres.read(CHUNK_SIZE)
            while len(data) > 0:
                dl += len(data)
                tfile.write(data)
                done = int(50 * dl / int(total_length))
                sys.stdout.write(f"\r[{'=' * done}{' ' * (50-done)}] {dl} bytes downloaded")
                sys.stdout.flush()
                data = fileres.read(CHUNK_SIZE)
            if filename.endswith('.zip'):
              with ZipFile(tfile) as zfile:
                zfile.extractall(destination_path)
            else:
              with tarfile.open(tfile.name) as tarfile:
                tarfile.extractall(destination_path)
            print(f'\nDownloaded and uncompressed: {directory}')
    except HTTPError as e:
        print(f'Failed to load (likely expired) {download_url} to path {destination_path}')
        continue
    except OSError as e:
        print(f'Failed to load {download_url} to path {destination_path}')
        continue

print('Data source import complete.')
# Out:
# Downloading keras-pretrained-models, 989248706 bytes compressed
# [==================================================] 989248706 bytes downloaded
# Downloaded and uncompressed: keras-pretrained-models
# Downloading brain-mri-images-for-brain-tumor-detection, 15828590 bytes compressed
# [==================================================] 15828590 bytes downloaded
# Downloaded and uncompressed: brain-mri-images-for-brain-tumor-detection
# Data source import complete.

# %%
import cv2
import os
import numpy as np
import pandas as pd
import seaborn as sns
import random
import matplotlib.pyplot as plt
import tensorflow as tf
from sklearn.utils import shuffle
import glob
from tensorflow.keras.models import Model,Sequential
from tensorflow.keras.layers import Input,Conv2D, Dense, Flatten ,Dropout ,MaxPooling2D,BatchNormalization,GlobalAveragePooling2D
from tensorflow.keras import layers, Sequential
from sklearn.model_selection import train_test_split
from tensorflow.keras.callbacks import EarlyStopping
from PIL import Image

import tensorflow as tf
from tensorflow import keras
import warnings
warnings.filterwarnings('ignore')

# %%
path_No = '/kaggle/input/brain-mri-images-for-brain-tumor-detection/no/*'
path_Yes = '/kaggle/input/brain-mri-images-for-brain-tumor-detection/yes/*'

tumor = []
no_tumor = []
random_state = 42

for file in glob.iglob(path_Yes):
    img = cv2.imread(file)      #Reading the images from the path
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)        #Changing the color from BGR to RGB
    img = cv2.resize(img, (128, 128))
    tumor.append((img, 1))  # Appending tuple with image and label 1 (indicating presence of tumor)

for file in glob.iglob(path_No):
    img = cv2.imread(file)
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    img = cv2.resize(img, (128, 128))
    no_tumor.append((img, 0))  # Appending tuple with image and label 0 (indicating absence of tumor)

# Concatenating the two lists and shuffle the data
all_data = tumor + no_tumor


# Splitting data and labels
data = np.array([item[0] for item in all_data])
labels = np.array([item[1] for item in all_data])

# %%
plt.figure(figsize=(15, 5))

# Display tumor images with label 'yes'
for i in range(3):
    plt.subplot(2, 3, i+1)
    plt.imshow(tumor[i][0])
    plt.title("Tumor: Yes")
    plt.axis('off')

# Display no_tumor images with label 'no'
for i in range(3):
    plt.subplot(2, 3, i+4)
    plt.imshow(no_tumor[i][0])
    plt.title("Tumor: No")
    plt.axis('off')

plt.tight_layout()
plt.show()

# %%
# Counting the occurrences of each class label
unique_labels, label_counts = np.unique(labels, return_counts=True)

plt.bar(unique_labels, label_counts, color=['blue', 'orange'])
plt.xticks(unique_labels, ['No Tumor', 'Tumor'])
plt.xlabel('Class Label')
plt.ylabel('Count')
plt.title('Distribution of Class Labels')
plt.show()

# %%
x_train, x_test, y_train, y_test = train_test_split(data, labels, test_size=0.20, random_state=42)

# %%
# Assuming x_train and x_test are your image datasets



# Normalize the pixel values to the range [0, 1]
x_train= x_train /255.0
x_test = x_test / 255.0

# %%
print("Minimum value of the scaled data:", x_train.min())
print("Maximum value of the scaled data:",  x_train.max())
# Out:
# Minimum value of the scaled data: 0.0
# Maximum value of the scaled data: 1.0

# %%
model = Sequential()

model.add(Conv2D(32, kernel_size=(3, 3), activation='relu', input_shape=(128, 128, 3)))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Conv2D(64, kernel_size=(3, 3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Conv2D(128, kernel_size=(3, 3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Flatten())
model.add(Dropout(0.5))
model.add(Dense(128, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(1, activation='sigmoid'))

# %%
model.compile(optimizer='Adam',loss='binary_crossentropy', metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 126, 126, 32)      896
#
#  max_pooling2d (MaxPooling2  (None, 63, 63, 32)        0
#  D)
#
#  conv2d_1 (Conv2D)           (None, 61, 61, 64)        18496
#
#  max_pooling2d_1 (MaxPoolin  (None, 30, 30, 64)        0
#  g2D)
#
#  conv2d_2 (Conv2D)           (None, 28, 28, 128)       73856
#
#  max_pooling2d_2 (MaxPoolin  (None, 14, 14, 128)       0
#  g2D)
#
#  flatten (Flatten)           (None, 25088)             0
#
#  dropout (Dropout)           (None, 25088)             0
#
#  dense (Dense)               (None, 128)               3211392
#
#  dropout_1 (Dropout)         (None, 128)               0
#
#  dense_1 (Dense)             (None, 1)                 129
#
# =================================================================
# Total params: 3304769 (12.61 MB)
# Trainable params: 3304769 (12.61 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# Define callbacks function
class myCallback(tf.keras.callbacks.Callback):
    def on_epoch_end(self, epoch, logs={}):
        if logs.get('accuracy') > 0.99:
            print("\nReached 99% accuracy so cancelling training!")
            self.model.stop_training = True

back = myCallback()

# %%
history = model.fit(x_train,
                    y_train,
                    epochs=100,
                    batch_size=32,
                    validation_split=0.2,
                   callbacks=[back])
# Out:
# Epoch 1/100
# 6/6 [==============================] - 8s 957ms/step - loss: 0.8212 - accuracy: 0.5714 - val_loss: 0.6471 - val_accuracy: 0.7805
# Epoch 2/100
# 6/6 [==============================] - 6s 1s/step - loss: 0.5794 - accuracy: 0.7453 - val_loss: 0.6736 - val_accuracy: 0.5854
# Epoch 3/100
# 6/6 [==============================] - 6s 896ms/step - loss: 0.4700 - accuracy: 0.7578 - val_loss: 0.6780 - val_accuracy: 0.5610
# Epoch 4/100
# 6/6 [==============================] - 5s 894ms/step - loss: 0.4891 - accuracy: 0.7702 - val_loss: 0.7862 - val_accuracy: 0.7073
# Epoch 5/100
# 6/6 [==============================] - 6s 951ms/step - loss: 0.5036 - accuracy: 0.8137 - val_loss: 0.5723 - val_accuracy: 0.7561
# Epoch 6/100
# 6/6 [==============================] - 5s 791ms/step - loss: 0.4785 - accuracy: 0.7826 - val_loss: 0.5834 - val_accuracy: 0.7317
# Epoch 7/100
# 6/6 [==============================] - 6s 1s/step - loss: 0.4454 - accuracy: 0.7578 - val_loss: 0.6133 - val_accuracy: 0.7805
# Epoch 8/100
# 6/6 [==============================] - 5s 875ms/step - loss: 0.4200 - accuracy: 0.8199 - val_loss: 0.6896 - val_accuracy: 0.8049
# Epoch 9/100
# 6/6 [==============================] - 6s 1s/step - loss: 0.3954 - accuracy: 0.8509 - val_loss: 0.6631 - val_accuracy: 0.7805
# Epoch 10/100
# 6/6 [==============================] - 5s 803ms/step - loss: 0.3914 - accuracy: 0.8447 - val_loss: 0.6614 - val_accuracy: 0.7805
# Epoch 11/100
# 6/6 [==============================] - 5s 889ms/step - loss: 0.3220 - accuracy: 0.8820 - val_loss: 0.7091 - val_accuracy: 0.8049
# Epoch 12/100
# 6/6 [==============================] - 6s 967ms/step - loss: 0.3071 - accuracy: 0.8758 - val_loss: 0.7882 - val_accuracy: 0.8049
# Epoch 13/100
# 6/6 [==============================] - 5s 821ms/step - loss: 0.2811 - accuracy: 0.8634 - val_loss: 0.7875 - val_accuracy: 0.8049
# Epoch 14/100
# 6/6 [==============================] - 7s 1s/step - loss: 0.3756 - accuracy: 0.8509 - val_loss: 0.7278 - val_accuracy: 0.7317
# Epoch 15/100
# 6/6 [==============================] - 5s 809ms/step - loss: 0.3441 - accuracy: 0.9130 - val_loss: 0.6328 - val_accuracy: 0.7073
# Epoch 16/100
# 6/6 [==============================] - 6s 1s/step - loss: 0.3694 - accuracy: 0.9130 - val_loss: 0.6804 - val_accuracy: 0.7317
# Epoch 17/100
# 6/6 [==============================] - 5s 870ms/step - loss: 0.3126 - accuracy: 0.8758 - val_loss: 0.7105 - val_accuracy: 0.7317
# Epoch 18/100
# 6/6 [==============================] - 5s 820ms/step - loss: 0.3898 - accuracy: 0.8075 - val_loss: 0.6349 - val_accuracy: 0.7561
# Epoch 19/100
# 6/6 [==============================] - 7s 1s/step - loss: 0.3112 - accuracy: 0.9068 - val_loss: 0.6326 - val_accuracy: 0.7561
# Epoch 20/100
# 6/6 [==============================] - 5s 839ms/step - loss: 0.2555 - accuracy: 0.8820 - val_loss: 0.7849 - val_accuracy: 0.7561
# Epoch 21/100
# 6/6 [==============================] - 6s 1s/step - loss: 0.2389 - accuracy: 0.9006 - val_loss: 0.7970 - val_accuracy: 0.7805
# Epoch 22/100
# 6/6 [==============================] - 5s 896ms/step - loss: 0.2105 - accuracy: 0.9255 - val_loss: 0.8368 - val_accuracy: 0.7561
# Epoch 23/100
# 6/6 [==============================] - 6s 1s/step - loss: 0.1677 - accuracy: 0.9255 - val_loss: 0.9216 - val_accuracy: 0.7561
# Epoch 24/100
# 6/6 [==============================] - 5s 875ms/step - loss: 0.1616 - accuracy: 0.9317 - val_loss: 0.8774 - val_accuracy: 0.8293
# Epoch 25/100
# 6/6 [==============================] - 5s 875ms/step - loss: 0.1368 - accuracy: 0.9565 - val_loss: 0.9480 - val_accuracy: 0.7805
# Epoch 26/100
# 6/6 [==============================] - 6s 907ms/step - loss: 0.1156 - accuracy: 0.9441 - val_loss: 1.0116 - val_accuracy: 0.8049
# Epoch 27/100
# 6/6 [==============================] - 5s 878ms/step - loss: 0.1162 - accuracy: 0.9379 - val_loss: 1.0966 - val_accuracy: 0.8049
# Epoch 28/100
# 6/6 [==============================] - 7s 1s/step - loss: 0.0864 - accuracy: 0.9752 - val_loss: 0.9165 - val_accuracy: 0.7805
# Epoch 29/100
# 6/6 [==============================] - 5s 831ms/step - loss: 0.1558 - accuracy: 0.9441 - val_loss: 0.6590 - val_accuracy: 0.7805
# Epoch 30/100
# 6/6 [==============================] - 6s 1s/step - loss: 0.1597 - accuracy: 0.9565 - val_loss: 0.6534 - val_accuracy: 0.8049
# Epoch 31/100
# 6/6 [==============================] - 5s 898ms/step - loss: 0.1442 - accuracy: 0.9565 - val_loss: 0.6832 - val_accuracy: 0.7805
# Epoch 32/100
# 6/6 [==============================] - 7s 1s/step - loss: 0.2146 - accuracy: 0.9255 - val_loss: 1.0396 - val_accuracy: 0.7805
# Epoch 33/100
# 6/6 [==============================] - 8s 1s/step - loss: 0.2401 - accuracy: 0.8882 - val_loss: 0.7127 - val_accuracy: 0.8293
# Epoch 34/100
# 6/6 [==============================] - 6s 1s/step - loss: 0.1547 - accuracy: 0.9503 - val_loss: 0.8048 - val_accuracy: 0.8049
# Epoch 35/100
# 6/6 [==============================] - 5s 824ms/step - loss: 0.0958 - accuracy: 0.9627 - val_loss: 1.1082 - val_accuracy: 0.7805
# Epoch 36/100
# 6/6 [==============================] - 5s 868ms/step - loss: 0.0748 - accuracy: 0.9689 - val_loss: 1.1050 - val_accuracy: 0.8293
# Epoch 37/100
# 6/6 [==============================] - 6s 901ms/step - loss: 0.0810 - accuracy: 0.9627 - val_loss: 1.2624 - val_accuracy: 0.8293
# Epoch 38/100
# 6/6 [==============================] - 5s 820ms/step - loss: 0.0993 - accuracy: 0.9627 - val_loss: 1.1368 - val_accuracy: 0.8293
# Epoch 39/100
# 6/6 [==============================] - ETA: 0s - loss: 0.0469 - accuracy: 0.9938
# Reached 99% accuracy so cancelling training!
# 6/6 [==============================] - 7s 1s/step - loss: 0.0469 - accuracy: 0.9938 - val_loss: 1.0897 - val_accuracy: 0.7805

# %%
# plot the accuracy and loss
plt.figure(figsize=(10, 5))
plt.subplot(1, 2, 1)
plt.plot(history.history["accuracy"], label="accuracy")
plt.plot(history.history["val_accuracy"], label="val_accuracy")
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.legend()
plt.title("Accuracy")
plt.show()

# %%
# model loss
plt.figure(figsize=(10, 5))
plt.subplot(1, 2, 2)
plt.plot(history.history["loss"], label="loss")
plt.plot(history.history["val_loss"], label="val_loss")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.legend()
plt.title("Loss")
plt.show()

# %%
# Evaluate the model
test_loss, test_acc = model.evaluate(x_test, y_test)
print("Test Loss:", test_loss)
print("Test Accuracy:", test_acc)
# Out:
# 2/2 [==============================] - 0s 141ms/step - loss: 0.7802 - accuracy: 0.7843
# Test Loss: 0.7802457809448242
# Test Accuracy: 0.7843137383460999

# %%
# Assuming 'model' is your trained Keras model
model.save("brain_tumor.h5")
